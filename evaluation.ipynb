# %%
# %load_ext autoreload
# %autoreload 2

# %%
import argparse
# import numpy as np
import os
from tqdm import tqdm
import pandas as pd
import trimesh
import torch
from evaluation.eval_meshes import MeshEvaluator
from utils.io import load_pointcloud
import yaml
from data import dataset

# %%
path="generation.yaml"
with open(path, 'r') as f:
    cfg = yaml.load(f, Loader=yaml.SafeLoader)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Shorthands
out_dir = cfg['training']['out_dir']
# generation_dir = os.path.join(out_dir, cfg['generation']['generation_dir'])
generation_dir = "out/pretrained"
#generation_dir = "out/pretrained_model_meshes"
out_file = os.path.join(generation_dir, 'eval_meshes_full.pkl')
out_file_class = os.path.join(generation_dir, 'eval_meshes.csv')

# %%
# Dataset
points_field = dataset.PointsField(
    cfg['data']['points_iou_file'], 
    unpackbits=cfg['data']['points_unpackbits'],
)
pointcloud_field = dataset.PointCloudField(
    cfg['data']['pointcloud_chamfer_file']
)
fields = {
    'points_iou': points_field,
    'pointcloud_chamfer': pointcloud_field,
    'idx': dataset.IndexField(),
}

print('Test split: ', cfg['data']['test_split'])

dataset_folder = cfg['data']['path']
dataset = dataset.Shapes3dDataset(
    dataset_folder, fields,
    cfg['data']['test_split'],
    categories=cfg['data']['classes'])
# Out:
# Test split:  test
# Test split:  test

# %%
# Evaluator
evaluator = MeshEvaluator(n_points=100000)

# Loader
test_loader = torch.utils.data.DataLoader(
    dataset, batch_size=1, num_workers=0, shuffle=False)

# %%
torch.cuda.empty_cache()

# %%
# Evaluate all classes
eval_dicts = []
print('Evaluating meshes...')
for it, data in enumerate(tqdm(test_loader)):
    if data is None:
        print('Invalid data.')
        continue

    # Output folders
#     if not args.eval_input:
#         mesh_dir = os.path.join(generation_dir, 'meshes')
#         pointcloud_dir = os.path.join(generation_dir, 'pointcloud')
#     else:
    mesh_dir = os.path.join(generation_dir, 'meshes')
    pointcloud_dir = os.path.join(generation_dir, 'pointcloud')

    # Get index etc.
    idx = data['idx'].item()

    try:
        model_dict = dataset.get_model_dict(idx)
    except AttributeError:
        model_dict = {'model': str(idx), 'category': 'n/a'}
    
    modelname = model_dict['model']
    category_id = model_dict['category']

    try:
        category_name = dataset.metadata[category_id].get('name', 'n/a')
    except AttributeError:
        category_name = 'n/a'

    if category_id != 'n/a':
        mesh_dir = os.path.join(mesh_dir, category_id)
        pointcloud_dir = os.path.join(pointcloud_dir, category_id)

    # Evaluate
    pointcloud_tgt = data['pointcloud_chamfer'].squeeze(0).numpy()
    normals_tgt = data['pointcloud_chamfer.normals'].squeeze(0).numpy()
    points_tgt = data['points_iou'].squeeze(0).numpy()
    occ_tgt = data['points_iou.occ'].squeeze(0).numpy()

    # Evaluating mesh and pointcloud
    # Start row and put basic informatin inside
    eval_dict = {
        'idx': idx,
        'class id': category_id,
        'class name': category_name,
        'modelname': modelname,
    }
    eval_dicts.append(eval_dict)

    # Evaluate mesh
    if cfg['test']['eval_mesh']:
        mesh_file = os.path.join(mesh_dir, '%s.off' % modelname)

        if os.path.exists(mesh_file):
            mesh = trimesh.load(mesh_file, process=False)
            eval_dict_mesh = evaluator.eval_mesh(
                mesh, pointcloud_tgt, normals_tgt, points_tgt, occ_tgt)
            for k, v in eval_dict_mesh.items():
                eval_dict[k + ' (mesh)'] = v
        else:
            print('Warning: mesh does not exist: %s' % mesh_file)

    # Evaluate point cloud
    if cfg['test']['eval_pointcloud']:
        pointcloud_file = os.path.join(
            pointcloud_dir, '%s.ply' % modelname)

        if os.path.exists(pointcloud_file):
            pointcloud = load_pointcloud(pointcloud_file)
            eval_dict_pcl = evaluator.eval_pointcloud(
                pointcloud, pointcloud_tgt)
            for k, v in eval_dict_pcl.items():
                eval_dict[k + ' (pcl)'] = v
        else:
            print('Warning: pointcloud does not exist: %s'
                    % pointcloud_file)
# Out:
# Evaluating meshes...
# Evaluating meshes...
#   9%|███████▋                                                                          | 819/8751 [05:00<1:02:28,  2.12it/s]WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
# WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
#   9%|███████▋                                                                          | 823/8751 [05:02<1:07:13,  1.97it/s]WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
# WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
#   9%|███████▉                                                                            | 831/8751 [05:05<58:22,  2.26it/s]WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
# WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
#  10%|████████                                                                            | 836/8751 [05:07<56:27,  2.34it/s]WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
# WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
#  10%|████████                                                                            | 845/8751 [05:11<58:28,  2.25it/s]WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
# WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
#  10%|████████▏                                                                           | 849/8751 [05:12<55:43,  2.36it/s]WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
#  10%|████████▏                                                                           | 849/8751 [05:12<55:43,  2.36it/s]WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
#  10%|████████▏                                                                           | 854/8751 [05:14<51:35,  2.55it/s]WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
# WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
#  10%|████████▏                                                                           | 856/8751 [05:15<43:09,  3.05it/s]WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
# WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
#  10%|████████▍                                                                         | 903/8751 [05:40<1:13:45,  1.77it/s]WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
# WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
#  11%|████████▉                                                                           | 925/8751 [05:52<57:36,  2.26it/s]WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
# WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
#  11%|█████████▎                                                                        | 995/8751 [06:27<1:00:47,  2.13it/s]WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
# WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
#  12%|█████████▋                                                                         | 1019/8751 [06:39<59:36,  2.16it/s]WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
# WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
#  12%|█████████▊                                                                         | 1031/8751 [06:45<57:14,  2.25it/s]WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
# WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
#  12%|█████████▌                                                                       | 1038/8751 [06:48<1:01:20,  2.10it/s]WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
# WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
#  12%|██████████                                                                         | 1056/8751 [06:56<57:46,  2.22it/s]WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
# WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
#  13%|██████████▏                                                                      | 1094/8751 [07:15<1:00:31,  2.11it/s]WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
# WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
#  13%|██████████▍                                                                        | 1097/8751 [07:16<53:28,  2.39it/s]WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
#  13%|██████████▍                                                                        | 1099/8751 [07:16<42:57,  2.97it/s]WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
#  13%|██████████▎                                                                      | 1115/8751 [07:26<1:21:47,  1.56it/s]WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
# WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
#  13%|██████████▍                                                                      | 1124/8751 [07:30<1:18:00,  1.63it/s]WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
# WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
#  13%|██████████▌                                                                      | 1144/8751 [07:41<1:06:29,  1.91it/s]WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
# WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
#  13%|██████████▊                                                                        | 1146/8751 [07:41<49:37,  2.55it/s]WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
# WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
#  14%|███████████▏                                                                       | 1183/8751 [08:01<51:21,  2.46it/s]WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
# WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
#  14%|███████████▏                                                                     | 1204/8751 [08:13<1:16:07,  1.65it/s]WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
# WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
#  14%|███████████▍                                                                       | 1212/8751 [08:16<56:56,  2.21it/s]WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
# WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
#  14%|███████████▋                                                                       | 1233/8751 [08:25<55:29,  2.26it/s]WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
# WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
#  14%|███████████▋                                                                       | 1235/8751 [08:26<43:50,  2.86it/s]WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
# WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
#  14%|███████████▌                                                                     | 1243/8751 [08:30<1:08:32,  1.83it/s]WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
# WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
#  14%|███████████▉                                                                       | 1265/8751 [08:38<53:06,  2.35it/s]WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
# WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
#  20%|████████████████▊                                                                  | 1774/8751 [11:28<50:13,  2.31it/s]WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
# WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
#  27%|█████████████████████▍                                                           | 2320/8751 [15:50<1:21:07,  1.32it/s]WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
# WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
#  27%|█████████████████████▉                                                           | 2376/8751 [16:31<1:18:52,  1.35it/s]
# Warning: contains1 != contains2 for some points.
# Warning: contains1 != contains2 for some points.
#  44%|████████████████████████████████████▊                                              | 3880/8751 [33:38<52:43,  1.54it/s]WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
# WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
#  51%|██████████████████████████████████████████▏                                        | 4454/8751 [41:46<30:17,  2.36it/s]WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
# WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
#  57%|███████████████████████████████████████████████▎                                   | 4992/8751 [46:55<50:17,  1.25it/s]
# Warning: contains1 != contains2 for some points.
# Warning: contains1 != contains2 for some points.
#  75%|██████████████████████████████████████████████████████████████▏                    | 6552/8751 [59:23<27:52,  1.31it/s]WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
# WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
#  93%|███████████████████████████████████████████████████████████████████████████▍     | 8153/8751 [1:17:41<10:28,  1.05s/it]WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
# WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
#  99%|████████████████████████████████████████████████████████████████████████████████ | 8654/8751 [1:23:45<01:01,  1.59it/s]WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
# WARNING:evaluation.eval_meshes:Empty pointcloud / mesh detected!
# 100%|█████████████████████████████████████████████████████████████████████████████████| 8751/8751 [1:24:52<00:00,  1.72it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████████| 8751/8751 [1:24:52<00:00,  1.72it/s]

# %%
# Create pandas dataframe and save
eval_df = pd.DataFrame(eval_dicts)
eval_df.set_index(['idx'], inplace=True)
eval_df.to_pickle(out_file)

# Create CSV file  with main statistics
eval_df_class = eval_df.drop('modelname', axis=1).groupby(by=['class name']).mean()
eval_df_class.to_csv(out_file_class)

# Print results
eval_df_class.loc['mean'] = eval_df_class.mean()
print(eval_df_class)
# Out:
#                                                    class id  \
# class name
# airplane,aeroplane,plane                                inf
# bench                                                   inf
# cabinet                                                 inf
# car,auto,automobile,machine,motorcar                    inf
# chair                                                   inf
# display,video display                                   inf
# lamp                                                    inf
# loudspeaker,speaker,speaker unit,loudspeaker sy...      inf
# rifle                                                   inf
# sofa,couch,lounge                                       inf
# table                                                   inf
# telephone,phone,telephone set                           inf
# vessel,watercraft                                       inf
# mean                                                    inf
#
#                                                     completeness (mesh)  \
# class name
# airplane,aeroplane,plane                                       0.057397
# bench                                                          0.091924
# cabinet                                                        0.035943
# car,auto,automobile,machine,motorcar                           0.026109
# chair                                                          0.066832
# display,video display                                          0.064547
# lamp                                                           0.202937
# loudspeaker,speaker,speaker unit,loudspeaker sy...             0.050593
# rifle                                                          0.035357
# sofa,couch,lounge                                              0.040723
# table                                                          0.062603
# telephone,phone,telephone set                                  0.029386
# vessel,watercraft                                              0.046295
# mean                                                           0.062357
#
#                                                     accuracy (mesh)  \
# class name
# airplane,aeroplane,plane                                   0.024585
# bench                                                      0.054597
# cabinet                                                    0.032764
# car,auto,automobile,machine,motorcar                       0.020388
# chair                                                      0.043887
# display,video display                                      0.070248
# lamp                                                       0.158649
# loudspeaker,speaker,speaker unit,loudspeaker sy...         0.050114
# rifle                                                      0.028929
# sofa,couch,lounge                                          0.045323
# table                                                      0.042881
# telephone,phone,telephone set                              0.031330
# vessel,watercraft                                          0.041344
# mean                                                       0.049618
#
#                                                     normals completeness (mesh)  \
# class name
# airplane,aeroplane,plane                                               0.606652
# bench                                                                  0.554988
# cabinet                                                                0.692876
# car,auto,automobile,machine,motorcar                                   0.682305
# chair                                                                  0.649543
# display,video display                                                  0.627039
# lamp                                                                   0.500718
# loudspeaker,speaker,speaker unit,loudspeaker sy...                     0.670111
# rifle                                                                  0.614211
# sofa,couch,lounge                                                      0.632013
# table                                                                  0.649810
# telephone,phone,telephone set                                          0.814717
# vessel,watercraft                                                      0.599883
# mean                                                                   0.638067
#
#                                                     normals accuracy (mesh)  \
# class name
# airplane,aeroplane,plane                                           0.708484
# bench                                                              0.603411
# cabinet                                                            0.751992
# car,auto,automobile,machine,motorcar                               0.766149
# chair                                                              0.706340
# display,video display                                              0.670340
# lamp                                                               0.520255
# loudspeaker,speaker,speaker unit,loudspeaker sy...                 0.711556
# rifle                                                              0.656118
# sofa,couch,lounge                                                  0.666157
# table                                                              0.715406
# telephone,phone,telephone set                                      0.828437
# vessel,watercraft                                                  0.617063
# mean                                                               0.686285
#
#                                                     normals (mesh)  \
# class name
# airplane,aeroplane,plane                                  0.657568
# bench                                                     0.579199
# cabinet                                                   0.722434
# car,auto,automobile,machine,motorcar                      0.724227
# chair                                                     0.677942
# display,video display                                     0.648690
# lamp                                                      0.510487
# loudspeaker,speaker,speaker unit,loudspeaker sy...        0.690834
# rifle                                                     0.635164
# sofa,couch,lounge                                         0.649085
# table                                                     0.682608
# telephone,phone,telephone set                             0.821577
# vessel,watercraft                                         0.608473
# mean                                                      0.662176
#
#                                                     completeness2 (mesh)  \
# class name
# airplane,aeroplane,plane                                        0.008779
# bench                                                           0.026924
# cabinet                                                         0.002615
# car,auto,automobile,machine,motorcar                            0.001299
# chair                                                           0.016540
# display,video display                                           0.020915
# lamp                                                            0.217016
# loudspeaker,speaker,speaker unit,loudspeaker sy...              0.005580
# rifle                                                           0.004445
# sofa,couch,lounge                                               0.003706
# table                                                           0.016529
# telephone,phone,telephone set                                   0.002573
# vessel,watercraft                                               0.012288
# mean                                                            0.026093
#
#                                                     accuracy2 (mesh)  \
# class name
# airplane,aeroplane,plane                                    0.001201
# bench                                                       0.014247
# cabinet                                                     0.002094
# car,auto,automobile,machine,motorcar                        0.001139
# chair                                                       0.008049
# display,video display                                       0.021992
# lamp                                                        0.188208
# loudspeaker,speaker,speaker unit,loudspeaker sy...          0.005421
# rifle                                                       0.003118
# sofa,couch,lounge                                           0.004887
# table                                                       0.007409
# telephone,phone,telephone set                               0.002602
# vessel,watercraft                                           0.011345
# mean                                                        0.020901
#
#                                                     chamfer-L2 (mesh)  \
# class name
# airplane,aeroplane,plane                                     0.004990
# bench                                                        0.012355
# cabinet                                                      0.002355
# car,auto,automobile,machine,motorcar                         0.001219
# chair                                                        0.007878
# display,video display                                        0.007790
# lamp                                                         0.022550
# loudspeaker,speaker,speaker unit,loudspeaker sy...           0.005500
# rifle                                                        0.003782
# sofa,couch,lounge                                            0.004297
# table                                                        0.008452
# telephone,phone,telephone set                                0.002587
# vessel,watercraft                                            0.004075
# mean                                                         0.006756
#
#                                                     chamfer-L1 (mesh)  \
# class name
# airplane,aeroplane,plane                                     0.040991
# bench                                                        0.068678
# cabinet                                                      0.034354
# car,auto,automobile,machine,motorcar                         0.023248
# chair                                                        0.052881
# display,video display                                        0.059761
# lamp                                                         0.080942
# loudspeaker,speaker,speaker unit,loudspeaker sy...           0.050353
# rifle                                                        0.032143
# sofa,couch,lounge                                            0.043023
# table                                                        0.050765
# telephone,phone,telephone set                                0.030358
# vessel,watercraft                                            0.039446
# mean                                                         0.046688
#
#                                                     iou (mesh)  chamfer (mesh)
# class name
# airplane,aeroplane,plane                              0.310173             NaN
# bench                                                 0.116784             6.0
# cabinet                                               0.549131             NaN
# car,auto,automobile,machine,motorcar                  0.582137             NaN
# chair                                                 0.310968             6.0
# display,video display                                 0.296242             6.0
# lamp                                                  0.188571             6.0
# loudspeaker,speaker,speaker unit,loudspeaker sy...    0.510967             NaN
# rifle                                                 0.254852             NaN
# sofa,couch,lounge                                     0.400559             NaN
# table                                                 0.221610             6.0
# telephone,phone,telephone set                         0.515147             NaN
# vessel,watercraft                                     0.289445             6.0
# mean                                                  0.349737             6.0
#                                                    class id  \
# class name
# airplane,aeroplane,plane                                inf
# bench                                                   inf
# cabinet                                                 inf
# car,auto,automobile,machine,motorcar                    inf
# chair                                                   inf
# display,video display                                   inf
# lamp                                                    inf
# loudspeaker,speaker,speaker unit,loudspeaker sy...      inf
# rifle                                                   inf
# sofa,couch,lounge                                       inf
# table                                                   inf
# telephone,phone,telephone set                           inf
# vessel,watercraft                                       inf
# mean                                                    inf
#
#                                                     completeness (mesh)  \
# class name
# airplane,aeroplane,plane                                       0.057397
# bench                                                          0.091924
# cabinet                                                        0.035943
# car,auto,automobile,machine,motorcar                           0.026109
# chair                                                          0.066832
# display,video display                                          0.064547
# lamp                                                           0.202937
# loudspeaker,speaker,speaker unit,loudspeaker sy...             0.050593
# rifle                                                          0.035357
# sofa,couch,lounge                                              0.040723
# table                                                          0.062603
# telephone,phone,telephone set                                  0.029386
# vessel,watercraft                                              0.046295
# mean                                                           0.062357
#
#                                                     accuracy (mesh)  \
# class name
# airplane,aeroplane,plane                                   0.024585
# bench                                                      0.054597
# cabinet                                                    0.032764
# car,auto,automobile,machine,motorcar                       0.020388
# chair                                                      0.043887
# display,video display                                      0.070248
# lamp                                                       0.158649
# loudspeaker,speaker,speaker unit,loudspeaker sy...         0.050114
# rifle                                                      0.028929
# sofa,couch,lounge                                          0.045323
# table                                                      0.042881
# telephone,phone,telephone set                              0.031330
# vessel,watercraft                                          0.041344
# mean                                                       0.049618
#
#                                                     normals completeness (mesh)  \
# class name
# airplane,aeroplane,plane                                               0.606652
# bench                                                                  0.554988
# cabinet                                                                0.692876
# car,auto,automobile,machine,motorcar                                   0.682305
# chair                                                                  0.649543
# display,video display                                                  0.627039
# lamp                                                                   0.500718
# loudspeaker,speaker,speaker unit,loudspeaker sy...                     0.670111
# rifle                                                                  0.614211
# sofa,couch,lounge                                                      0.632013
# table                                                                  0.649810
# telephone,phone,telephone set                                          0.814717
# vessel,watercraft                                                      0.599883
# mean                                                                   0.638067
#
#                                                     normals accuracy (mesh)  \
# class name
# airplane,aeroplane,plane                                           0.708484
# bench                                                              0.603411
# cabinet                                                            0.751992
# car,auto,automobile,machine,motorcar                               0.766149
# chair                                                              0.706340
# display,video display                                              0.670340
# lamp                                                               0.520255
# loudspeaker,speaker,speaker unit,loudspeaker sy...                 0.711556
# rifle                                                              0.656118
# sofa,couch,lounge                                                  0.666157
# table                                                              0.715406
# telephone,phone,telephone set                                      0.828437
# vessel,watercraft                                                  0.617063
# mean                                                               0.686285
#
#                                                     normals (mesh)  \
# class name
# airplane,aeroplane,plane                                  0.657568
# bench                                                     0.579199
# cabinet                                                   0.722434
# car,auto,automobile,machine,motorcar                      0.724227
# chair                                                     0.677942
# display,video display                                     0.648690
# lamp                                                      0.510487
# loudspeaker,speaker,speaker unit,loudspeaker sy...        0.690834
# rifle                                                     0.635164
# sofa,couch,lounge                                         0.649085
# table                                                     0.682608
# telephone,phone,telephone set                             0.821577
# vessel,watercraft                                         0.608473
# mean                                                      0.662176
#
#                                                     completeness2 (mesh)  \
# class name
# airplane,aeroplane,plane                                        0.008779
# bench                                                           0.026924
# cabinet                                                         0.002615
# car,auto,automobile,machine,motorcar                            0.001299
# chair                                                           0.016540
# display,video display                                           0.020915
# lamp                                                            0.217016
# loudspeaker,speaker,speaker unit,loudspeaker sy...              0.005580
# rifle                                                           0.004445
# sofa,couch,lounge                                               0.003706
# table                                                           0.016529
# telephone,phone,telephone set                                   0.002573
# vessel,watercraft                                               0.012288
# mean                                                            0.026093
#
#                                                     accuracy2 (mesh)  \
# class name
# airplane,aeroplane,plane                                    0.001201
# bench                                                       0.014247
# cabinet                                                     0.002094
# car,auto,automobile,machine,motorcar                        0.001139
# chair                                                       0.008049
# display,video display                                       0.021992
# lamp                                                        0.188208
# loudspeaker,speaker,speaker unit,loudspeaker sy...          0.005421
# rifle                                                       0.003118
# sofa,couch,lounge                                           0.004887
# table                                                       0.007409
# telephone,phone,telephone set                               0.002602
# vessel,watercraft                                           0.011345
# mean                                                        0.020901
#
#                                                     chamfer-L2 (mesh)  \
# class name
# airplane,aeroplane,plane                                     0.004990
# bench                                                        0.012355
# cabinet                                                      0.002355
# car,auto,automobile,machine,motorcar                         0.001219
# chair                                                        0.007878
# display,video display                                        0.007790
# lamp                                                         0.022550
# loudspeaker,speaker,speaker unit,loudspeaker sy...           0.005500
# rifle                                                        0.003782
# sofa,couch,lounge                                            0.004297
# table                                                        0.008452
# telephone,phone,telephone set                                0.002587
# vessel,watercraft                                            0.004075
# mean                                                         0.006756
#
#                                                     chamfer-L1 (mesh)  \
# class name
# airplane,aeroplane,plane                                     0.040991
# bench                                                        0.068678
# cabinet                                                      0.034354
# car,auto,automobile,machine,motorcar                         0.023248
# chair                                                        0.052881
# display,video display                                        0.059761
# lamp                                                         0.080942
# loudspeaker,speaker,speaker unit,loudspeaker sy...           0.050353
# rifle                                                        0.032143
# sofa,couch,lounge                                            0.043023
# table                                                        0.050765
# telephone,phone,telephone set                                0.030358
# vessel,watercraft                                            0.039446
# mean                                                         0.046688
#
#                                                     iou (mesh)  chamfer (mesh)
# class name
# airplane,aeroplane,plane                              0.310173             NaN
# bench                                                 0.116784             6.0
# cabinet                                               0.549131             NaN
# car,auto,automobile,machine,motorcar                  0.582137             NaN
# chair                                                 0.310968             6.0
# display,video display                                 0.296242             6.0
# lamp                                                  0.188571             6.0
# loudspeaker,speaker,speaker unit,loudspeaker sy...    0.510967             NaN
# rifle                                                 0.254852             NaN
# sofa,couch,lounge                                     0.400559             NaN
# table                                                 0.221610             6.0
# telephone,phone,telephone set                         0.515147             NaN
# vessel,watercraft                                     0.289445             6.0
# mean                                                  0.349737             6.0

# %%
# Create pandas dataframe and save
eval_df = pd.DataFrame(eval_dicts)
eval_df.set_index(['idx'], inplace=True)
eval_df
# Out:
#       class id                class name  \
# idx
# 0     02691156  airplane,aeroplane,plane
# 1     02691156  airplane,aeroplane,plane
# 2     02691156  airplane,aeroplane,plane
# 3     02691156  airplane,aeroplane,plane
# 4     02691156  airplane,aeroplane,plane
# ...        ...                       ...
# 8746  03001627                     chair
# 8747  03001627                     chair
# 8748  03001627                     chair
# 8749  03001627                     chair
# 8750  03001627                     chair
#
#                                   modelname  completeness (mesh)  \
# idx
# 0          d18592d9615b01bbbc0909d98a1ff2b4             0.056841
# 1          d18f2aeae4146464bd46d022fd7d80aa             0.038793
# 2          d199612c22fe9313f4fb6842b3610149             0.041992
# 3          d1a887a47991d1b3bc0909d98a1ff2b4             0.045096
# 4          d1a8e79eebf4a0b1579c3d4943e463ef             0.055582
# ...                                     ...                  ...
# 8746  u6028f63e-4111-4412-9098-fe5f4f0c7c83             0.229026
# 8747  ub5d972a1-de16-4d0a-aa40-85cd3a69aa8a             0.034557
# 8748  uca24feec-f0c0-454c-baaf-561530686f40             0.023801
# 8749  udf068a6b-e65b-430b-bc17-611b062e2e34             0.069733
# 8750  ue639c33f-d415-458c-8ff8-2ef68135af15             0.047552
#
#       accuracy (mesh)  normals completeness (mesh)  normals accuracy (mesh)  \
# idx
# 0            0.020662                     0.626500                 0.765092
# 1            0.016124                     0.674373                 0.794593
# 2            0.018134                     0.650054                 0.712112
# 3            0.017325                     0.629339                 0.782354
# 4            0.020457                     0.590429                 0.794569
# ...               ...                          ...                      ...
# 8746         0.142582                     0.423708                 0.312294
# 8747         0.031462                     0.696457                 0.705142
# 8748         0.024430                     0.679383                 0.713110
# 8749         0.022238                     0.722088                 0.848056
# 8750         0.022925                     0.673512                 0.798021
#
#       normals (mesh)  completeness2 (mesh)  accuracy2 (mesh)  \
# idx
# 0           0.695796              0.007578          0.000627
# 1           0.734483              0.004330          0.000350
# 2           0.681083              0.004905          0.000488
# 3           0.705846              0.005317          0.000431
# 4           0.692499              0.007230          0.000579
# ...              ...                   ...               ...
# 8746        0.368001              0.077058          0.032681
# 8747        0.700800              0.002846          0.002005
# 8748        0.696247              0.000949          0.000973
# 8749        0.785072              0.016626          0.000719
# 8750        0.735766              0.007856          0.000738
#
#       chamfer-L2 (mesh)  chamfer-L1 (mesh)  iou (mesh)  chamfer (mesh)
# idx
# 0              0.004103           0.038751    0.304348             NaN
# 1              0.002340           0.027459    0.370813             NaN
# 2              0.002697           0.030063    0.271663             NaN
# 3              0.002874           0.031211    0.365782             NaN
# 4              0.003905           0.038020    0.333981             NaN
# ...                 ...                ...         ...             ...
# 8746           0.054869           0.185804    0.049555             NaN
# 8747           0.002426           0.033009    0.234830             NaN
# 8748           0.000961           0.024116    0.316350             NaN
# 8749           0.008672           0.045986    0.355582             NaN
# 8750           0.004297           0.035238    0.288187             NaN
#
# [8751 rows x 14 columns]
#       class id                class name  \
# idx
# 0     02691156  airplane,aeroplane,plane
# 1     02691156  airplane,aeroplane,plane
# 2     02691156  airplane,aeroplane,plane
# 3     02691156  airplane,aeroplane,plane
# 4     02691156  airplane,aeroplane,plane
# ...        ...                       ...
# 8746  03001627                     chair
# 8747  03001627                     chair
# 8748  03001627                     chair
# 8749  03001627                     chair
# 8750  03001627                     chair
#
#                                   modelname  completeness (mesh)  \
# idx
# 0          d18592d9615b01bbbc0909d98a1ff2b4             0.056841
# 1          d18f2aeae4146464bd46d022fd7d80aa             0.038793
# 2          d199612c22fe9313f4fb6842b3610149             0.041992
# 3          d1a887a47991d1b3bc0909d98a1ff2b4             0.045096
# 4          d1a8e79eebf4a0b1579c3d4943e463ef             0.055582
# ...                                     ...                  ...
# 8746  u6028f63e-4111-4412-9098-fe5f4f0c7c83             0.229026
# 8747  ub5d972a1-de16-4d0a-aa40-85cd3a69aa8a             0.034557
# 8748  uca24feec-f0c0-454c-baaf-561530686f40             0.023801
# 8749  udf068a6b-e65b-430b-bc17-611b062e2e34             0.069733
# 8750  ue639c33f-d415-458c-8ff8-2ef68135af15             0.047552
#
#       accuracy (mesh)  normals completeness (mesh)  normals accuracy (mesh)  \
# idx
# 0            0.020662                     0.626500                 0.765092
# 1            0.016124                     0.674373                 0.794593
# 2            0.018134                     0.650054                 0.712112
# 3            0.017325                     0.629339                 0.782354
# 4            0.020457                     0.590429                 0.794569
# ...               ...                          ...                      ...
# 8746         0.142582                     0.423708                 0.312294
# 8747         0.031462                     0.696457                 0.705142
# 8748         0.024430                     0.679383                 0.713110
# 8749         0.022238                     0.722088                 0.848056
# 8750         0.022925                     0.673512                 0.798021
#
#       normals (mesh)  completeness2 (mesh)  accuracy2 (mesh)  \
# idx
# 0           0.695796              0.007578          0.000627
# 1           0.734483              0.004330          0.000350
# 2           0.681083              0.004905          0.000488
# 3           0.705846              0.005317          0.000431
# 4           0.692499              0.007230          0.000579
# ...              ...                   ...               ...
# 8746        0.368001              0.077058          0.032681
# 8747        0.700800              0.002846          0.002005
# 8748        0.696247              0.000949          0.000973
# 8749        0.785072              0.016626          0.000719
# 8750        0.735766              0.007856          0.000738
#
#       chamfer-L2 (mesh)  chamfer-L1 (mesh)  iou (mesh)  chamfer (mesh)
# idx
# 0              0.004103           0.038751    0.304348             NaN
# 1              0.002340           0.027459    0.370813             NaN
# 2              0.002697           0.030063    0.271663             NaN
# 3              0.002874           0.031211    0.365782             NaN
# 4              0.003905           0.038020    0.333981             NaN
# ...                 ...                ...         ...             ...
# 8746           0.054869           0.185804    0.049555             NaN
# 8747           0.002426           0.033009    0.234830             NaN
# 8748           0.000961           0.024116    0.316350             NaN
# 8749           0.008672           0.045986    0.355582             NaN
# 8750           0.004297           0.035238    0.288187             NaN
#
# [8751 rows x 14 columns]
